# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('housing_small.csv')

# %%
data
# Out:
#        sqft  bedrooms   age
# 0    2890.0         4   2.5
# 1    1985.0         4  53.0
# 2    3118.0         4  42.6
# 3    2683.0         1  10.4
# 4    1054.0         5   5.5
# ..      ...       ...   ...
# 295  3237.0         4  29.4
# 296  3445.0         3  20.0
# 297  2965.0         1  25.9
# 298  2905.0         1  46.8
# 299  2535.0         4  50.5
#
# [300 rows x 3 columns]
